# %% [markdown]
# # Import Packages

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Load Dataframe

# %%
# Load in dataframe from csv
df = pd.read_csv('exoplanets_data.csv')
df
# Out:
#        koi_name     disposition  \
# 0     K00752.01       CONFIRMED
# 1     K00752.02       CONFIRMED
# 2     K00753.01       CANDIDATE
# 3     K00754.01  FALSE POSITIVE
# 4     K00755.01       CONFIRMED
# ...         ...             ...
# 9559  K07985.01  FALSE POSITIVE
# 9560  K07986.01       CANDIDATE
# 9561  K07987.01  FALSE POSITIVE
# 9562  K07988.01       CANDIDATE
# 9563  K07989.01  FALSE POSITIVE
#
#                                     false_positive_type  \
# 0                                            NO_COMMENT
# 1                                            NO_COMMENT
# 2                                         DEEP_V_SHAPED
# 3      MOD_ODDEVEN_DV---MOD_ODDEVEN_ALT---DEEP_V_SHAPED
# 4                                            NO_COMMENT
# ...                                                 ...
# 9559  MOD_SEC_DV---PLANET_OCCULT_DV---MOD_SEC_ALT---...
# 9560                                         NO_COMMENT
# 9561                               CENT_RESOLVED_OFFSET
# 9562                  ALL_TRANS_CHASES---CENT_SATURATED
# 9563    CENT_RESOLVED_OFFSET---HALO_GHOST---EPHEM_MATCH
#
#       num_of_objects_around_star  fp_not_transit  fp_stellar_eclipse  \
# 0                              2               0                   0
# 1                              2               0                   0
# 2                              1               0                   0
# 3                              1               0                   1
# 4                              1               0                   0
# ...                          ...             ...                 ...
# 9559                           1               0                   1
# 9560                           1               0                   0
# 9561                           1               0                   0
# 9562                           1               0                   0
# 9563                           1               0                   0
#
#       fp_centroid_offset  fp_contamination  right_ascension  declination  ...  \
# 0                      0                 0        291.93423    48.141651  ...
# 1                      0                 0        291.93423    48.141651  ...
# 2                      0                 0        297.00482    48.134129  ...
# 3                      0                 0        285.53461    48.285210  ...
# 4                      0                 0        288.75488    48.226200  ...
# ...                  ...               ...              ...          ...  ...
# 9559                   1                 0        297.18875    47.093819  ...
# 9560                   0                 0        286.50937    47.163219  ...
# 9561                   1                 0        294.16489    47.176281  ...
# 9562                   0                 0        296.76288    47.145142  ...
# 9563                   1                 1        297.00977    47.121021  ...
#
#       centroid_declination  centroid_right_ascension_offset  \
# 0                48.141910                            0.430
# 1                48.141990                           -0.630
# 2                48.134120                           -0.021
# 3                48.285210                           -0.111
# 4                48.226260                           -0.010
# ...                    ...                              ...
# 9559             47.093686                            0.792
# 9560             47.163770                            0.100
# 9561             47.174720                            7.200
# 9562             47.145142                            0.310
# 9563             47.123490                            2.900
#
#       centroid_declination_offset  planet_star_right_ascension_offset  \
# 0                           0.940                           -0.000200
# 1                           1.230                            0.000660
# 2                          -0.038                            0.000700
# 3                           0.002                            0.003020
# 4                           0.230                            0.000080
# ...                           ...                                 ...
# 9559                       -0.484                           -0.000237
# 9560                        2.000                           -0.000018
# 9561                       -5.600                           -0.000720
# 9562                        0.010                           -0.000290
# 9563                        8.900                           -0.000230
#
#       planet_star_declination_offset  angular_offset_right_ascension  \
# 0                          -0.000550                          -0.010
# 1                          -0.001050                           0.390
# 2                           0.000600                          -0.025
# 3                          -0.001420                          -0.249
# 4                          -0.000070                           0.030
# ...                              ...                             ...
# 9559                        0.000178                           2.132
# 9560                       -0.000074                           0.740
# 9561                        0.000500                           3.410
# 9562                       -0.000100                           1.061
# 9563                       -0.000700                           1.020
#
#       angular_offset_declination  angular_offset_sky  insolation_flux  \
# 0                          0.200               0.200            93.59
# 1                          0.000               0.390             9.11
# 2                         -0.034               0.042            39.30
# 3                          0.147               0.289           891.96
# 4                         -0.090               0.100           926.16
# ...                          ...                 ...              ...
# 9559                      -1.757               2.763          4500.53
# 9560                      -0.250               0.780          1585.81
# 9561                      -3.650               5.000          5713.41
# 9562                       1.320               1.690            22.68
# 9563                       3.300               3.400           607.42
#
#       star_density
# 0          3.20796
# 1          3.02368
# 2          7.29555
# 3          0.22080
# 4          1.98635
# ...            ...
# 9559       0.16318
# 9560       0.50770
# 9561       8.97692
# 9562      85.88623
# 9563       1.40645
#
# [9564 rows x 54 columns]

# %% [markdown]
# # Split Into Data into Subsets

# %%
# Creating a row representing the total number of false positive flags marked true for each record
df['fp_total'] = df.fp_not_transit + df.fp_stellar_eclipse + df.fp_centroid_offset + df.fp_contamination
df.fp_total.value_counts()
# Out:
# fp_total
# 0      4799
# 1      3230
# 2      1042
# 3       489
# 4         3
# 465       1
# Name: count, dtype: int64

# %%
# Split df into two datasets - one for multiclass classification and one for binary class classification
# In order to have clearly disjoint classes in the multiclass case, choose only those with a confirmed disposition
# or those which have a false positive disposition and only 1 false positive flag set

multi_class_df = df.loc[((df.fp_total == 1) & (df.disposition == 'FALSE POSITIVE')) | (df.disposition == 'CONFIRMED')].copy()
binary_class_df = df.loc[(df.disposition == 'CONFIRMED') | (df.disposition == 'FALSE POSITIVE')].copy()

# %% [markdown]
# # Clean Multi-class Dataset

# %%
# Inspect multi_class_df
multi_class_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5953 entries, 0 to 9561
# Data columns (total 55 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   koi_name                            5953 non-null   object
#  1   disposition                         5953 non-null   object
#  2   false_positive_type                 5407 non-null   object
#  3   num_of_objects_around_star          5953 non-null   int64
#  4   fp_not_transit                      5953 non-null   int64
#  5   fp_stellar_eclipse                  5953 non-null   int64
#  6   fp_centroid_offset                  5953 non-null   int64
#  7   fp_contamination                    5953 non-null   int64
#  8   right_ascension                     5953 non-null   float64
#  9   declination                         5953 non-null   float64
#  10  g_band_mag                          5934 non-null   float64
#  11  r_band_mag                          5951 non-null   float64
#  12  i_band_mag                          5846 non-null   float64
#  13  z_band_mag                          5546 non-null   float64
#  14  j_band_mag                          5935 non-null   float64
#  15  h_band_mag                          5935 non-null   float64
#  16  k_band_mag                          5935 non-null   float64
#  17  kepler_band_mag                     5952 non-null   float64
#  18  num_of_transits                     5410 non-null   float64
#  19  max_single_event_stat               5410 non-null   float64
#  20  max_multi_event_stat                5410 non-null   float64
#  21  odd_even_depth_stat                 5231 non-null   float64
#  22  limb_dark_co4                       5766 non-null   float64
#  23  limb_dark_co3                       5766 non-null   float64
#  24  limb_dark_co2                       5766 non-null   float64
#  25  limb_dark_co1                       5766 non-null   float64
#  26  transit_signal_to_noise             5766 non-null   float64
#  27  planet_radius_earth                 5766 non-null   float64
#  28  orbit_semimajor_axis                5766 non-null   float64
#  29  impact                              5766 non-null   float64
#  30  transit_duration                    5953 non-null   float64
#  31  transit_depth                       5766 non-null   float64
#  32  orbital_period                      5953 non-null   float64
#  33  planet_star_radius_ratio            5766 non-null   float64
#  34  planet_star_distance_radius         5766 non-null   float64
#  35  inclination                         5765 non-null   float64
#  36  planet_temp                         5766 non-null   float64
#  37  star_temp                           5766 non-null   float64
#  38  star_surface_gravity                5766 non-null   float64
#  39  star_metallicity                    5752 non-null   float64
#  40  star_radius                         5766 non-null   float64
#  41  star_mass                           5766 non-null   float64
#  42  flux_weight_offset_sig              5274 non-null   float64
#  43  centroid_right_ascension            5696 non-null   float64
#  44  centroid_declination                5696 non-null   float64
#  45  centroid_right_ascension_offset     5710 non-null   float64
#  46  centroid_declination_offset         5710 non-null   float64
#  47  planet_star_right_ascension_offset  5436 non-null   float64
#  48  planet_star_declination_offset      5465 non-null   float64
#  49  angular_offset_right_ascension      5672 non-null   float64
#  50  angular_offset_declination          5672 non-null   float64
#  51  angular_offset_sky                  5672 non-null   float64
#  52  insolation_flux                     5799 non-null   float64
#  53  star_density                        5799 non-null   float64
#  54  fp_total                            5953 non-null   int64
# dtypes: float64(46), int64(6), object(3)
# memory usage: 2.5+ MB

# %%
# Helper function which label encodes class based off of disposition and false positive flags
def encode_disposition(row):
    if row.disposition == 'CONFIRMED':
        return 0
    if row.fp_not_transit:
        return 1
    elif row.fp_stellar_eclipse:
        return 2
    elif row.fp_centroid_offset:
        return 3
    elif row.fp_contamination:
        return 4

# The data is relatively clean and none of the columns have good options for imputing - drop rows containing nans
# Create a classification column using above helper function, then drop unneeded columns
multi_class_df.dropna(inplace = True)
multi_class_df['classification'] = multi_class_df.apply(lambda x: int(encode_disposition(x)), axis = 1)
multi_class_df.drop(['koi_name', 'false_positive_type', 'fp_total', 'disposition',
                     'fp_not_transit', 'fp_stellar_eclipse', 'fp_centroid_offset', 'fp_contamination'],
                    axis = 1, inplace = True)
multi_class_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4323 entries, 0 to 9561
# Data columns (total 48 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   num_of_objects_around_star          4323 non-null   int64
#  1   right_ascension                     4323 non-null   float64
#  2   declination                         4323 non-null   float64
#  3   g_band_mag                          4323 non-null   float64
#  4   r_band_mag                          4323 non-null   float64
#  5   i_band_mag                          4323 non-null   float64
#  6   z_band_mag                          4323 non-null   float64
#  7   j_band_mag                          4323 non-null   float64
#  8   h_band_mag                          4323 non-null   float64
#  9   k_band_mag                          4323 non-null   float64
#  10  kepler_band_mag                     4323 non-null   float64
#  11  num_of_transits                     4323 non-null   float64
#  12  max_single_event_stat               4323 non-null   float64
#  13  max_multi_event_stat                4323 non-null   float64
#  14  odd_even_depth_stat                 4323 non-null   float64
#  15  limb_dark_co4                       4323 non-null   float64
#  16  limb_dark_co3                       4323 non-null   float64
#  17  limb_dark_co2                       4323 non-null   float64
#  18  limb_dark_co1                       4323 non-null   float64
#  19  transit_signal_to_noise             4323 non-null   float64
#  20  planet_radius_earth                 4323 non-null   float64
#  21  orbit_semimajor_axis                4323 non-null   float64
#  22  impact                              4323 non-null   float64
#  23  transit_duration                    4323 non-null   float64
#  24  transit_depth                       4323 non-null   float64
#  25  orbital_period                      4323 non-null   float64
#  26  planet_star_radius_ratio            4323 non-null   float64
#  27  planet_star_distance_radius         4323 non-null   float64
#  28  inclination                         4323 non-null   float64
#  29  planet_temp                         4323 non-null   float64
#  30  star_temp                           4323 non-null   float64
#  31  star_surface_gravity                4323 non-null   float64
#  32  star_metallicity                    4323 non-null   float64
#  33  star_radius                         4323 non-null   float64
#  34  star_mass                           4323 non-null   float64
#  35  flux_weight_offset_sig              4323 non-null   float64
#  36  centroid_right_ascension            4323 non-null   float64
#  37  centroid_declination                4323 non-null   float64
#  38  centroid_right_ascension_offset     4323 non-null   float64
#  39  centroid_declination_offset         4323 non-null   float64
#  40  planet_star_right_ascension_offset  4323 non-null   float64
#  41  planet_star_declination_offset      4323 non-null   float64
#  42  angular_offset_right_ascension      4323 non-null   float64
#  43  angular_offset_declination          4323 non-null   float64
#  44  angular_offset_sky                  4323 non-null   float64
#  45  insolation_flux                     4323 non-null   float64
#  46  star_density                        4323 non-null   float64
#  47  classification                      4323 non-null   int64
# dtypes: float64(46), int64(2)
# memory usage: 1.6 MB

# %%
# Write dataframe to parquet file for further use
multi_class_df.to_csv('multi_class_data.csv')

# %% [markdown]
# # Clean Binary Class Dataset

# %%
# Inspect binary_class_df
binary_class_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7582 entries, 0 to 9563
# Data columns (total 55 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   koi_name                            7582 non-null   object
#  1   disposition                         7582 non-null   object
#  2   false_positive_type                 6898 non-null   object
#  3   num_of_objects_around_star          7582 non-null   int64
#  4   fp_not_transit                      7582 non-null   int64
#  5   fp_stellar_eclipse                  7582 non-null   int64
#  6   fp_centroid_offset                  7582 non-null   int64
#  7   fp_contamination                    7582 non-null   int64
#  8   right_ascension                     7582 non-null   float64
#  9   declination                         7582 non-null   float64
#  10  g_band_mag                          7547 non-null   float64
#  11  r_band_mag                          7575 non-null   float64
#  12  i_band_mag                          7455 non-null   float64
#  13  z_band_mag                          7063 non-null   float64
#  14  j_band_mag                          7557 non-null   float64
#  15  h_band_mag                          7557 non-null   float64
#  16  k_band_mag                          7557 non-null   float64
#  17  kepler_band_mag                     7581 non-null   float64
#  18  num_of_transits                     6901 non-null   float64
#  19  max_single_event_stat               6901 non-null   float64
#  20  max_multi_event_stat                6901 non-null   float64
#  21  odd_even_depth_stat                 6672 non-null   float64
#  22  limb_dark_co4                       7323 non-null   float64
#  23  limb_dark_co3                       7323 non-null   float64
#  24  limb_dark_co2                       7323 non-null   float64
#  25  limb_dark_co1                       7323 non-null   float64
#  26  transit_signal_to_noise             7323 non-null   float64
#  27  planet_radius_earth                 7323 non-null   float64
#  28  orbit_semimajor_axis                7323 non-null   float64
#  29  impact                              7323 non-null   float64
#  30  transit_duration                    7582 non-null   float64
#  31  transit_depth                       7323 non-null   float64
#  32  orbital_period                      7582 non-null   float64
#  33  planet_star_radius_ratio            7323 non-null   float64
#  34  planet_star_distance_radius         7323 non-null   float64
#  35  inclination                         7322 non-null   float64
#  36  planet_temp                         7323 non-null   float64
#  37  star_temp                           7323 non-null   float64
#  38  star_surface_gravity                7323 non-null   float64
#  39  star_metallicity                    7303 non-null   float64
#  40  star_radius                         7323 non-null   float64
#  41  star_mass                           7323 non-null   float64
#  42  flux_weight_offset_sig              6620 non-null   float64
#  43  centroid_right_ascension            7142 non-null   float64
#  44  centroid_declination                7142 non-null   float64
#  45  centroid_right_ascension_offset     7193 non-null   float64
#  46  centroid_declination_offset         7193 non-null   float64
#  47  planet_star_right_ascension_offset  6836 non-null   float64
#  48  planet_star_declination_offset      6864 non-null   float64
#  49  angular_offset_right_ascension      7074 non-null   float64
#  50  angular_offset_declination          7074 non-null   float64
#  51  angular_offset_sky                  7074 non-null   float64
#  52  insolation_flux                     7363 non-null   float64
#  53  star_density                        7363 non-null   float64
#  54  fp_total                            7582 non-null   int64
# dtypes: float64(46), int64(6), object(3)
# memory usage: 3.2+ MB

# %%
# Perform the same cleaning operations - drop unnecessary columns, drop rows with nans
binary_class_df.drop(['koi_name', 'false_positive_type', 'fp_total', 'fp_not_transit',
                      'fp_stellar_eclipse', 'fp_centroid_offset', 'fp_contamination'],
                    axis = 1, inplace = True)
binary_class_df.dropna(inplace = True)
binary_class_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5428 entries, 0 to 9563
# Data columns (total 48 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   disposition                         5428 non-null   object
#  1   num_of_objects_around_star          5428 non-null   int64
#  2   right_ascension                     5428 non-null   float64
#  3   declination                         5428 non-null   float64
#  4   g_band_mag                          5428 non-null   float64
#  5   r_band_mag                          5428 non-null   float64
#  6   i_band_mag                          5428 non-null   float64
#  7   z_band_mag                          5428 non-null   float64
#  8   j_band_mag                          5428 non-null   float64
#  9   h_band_mag                          5428 non-null   float64
#  10  k_band_mag                          5428 non-null   float64
#  11  kepler_band_mag                     5428 non-null   float64
#  12  num_of_transits                     5428 non-null   float64
#  13  max_single_event_stat               5428 non-null   float64
#  14  max_multi_event_stat                5428 non-null   float64
#  15  odd_even_depth_stat                 5428 non-null   float64
#  16  limb_dark_co4                       5428 non-null   float64
#  17  limb_dark_co3                       5428 non-null   float64
#  18  limb_dark_co2                       5428 non-null   float64
#  19  limb_dark_co1                       5428 non-null   float64
#  20  transit_signal_to_noise             5428 non-null   float64
#  21  planet_radius_earth                 5428 non-null   float64
#  22  orbit_semimajor_axis                5428 non-null   float64
#  23  impact                              5428 non-null   float64
#  24  transit_duration                    5428 non-null   float64
#  25  transit_depth                       5428 non-null   float64
#  26  orbital_period                      5428 non-null   float64
#  27  planet_star_radius_ratio            5428 non-null   float64
#  28  planet_star_distance_radius         5428 non-null   float64
#  29  inclination                         5428 non-null   float64
#  30  planet_temp                         5428 non-null   float64
#  31  star_temp                           5428 non-null   float64
#  32  star_surface_gravity                5428 non-null   float64
#  33  star_metallicity                    5428 non-null   float64
#  34  star_radius                         5428 non-null   float64
#  35  star_mass                           5428 non-null   float64
#  36  flux_weight_offset_sig              5428 non-null   float64
#  37  centroid_right_ascension            5428 non-null   float64
#  38  centroid_declination                5428 non-null   float64
#  39  centroid_right_ascension_offset     5428 non-null   float64
#  40  centroid_declination_offset         5428 non-null   float64
#  41  planet_star_right_ascension_offset  5428 non-null   float64
#  42  planet_star_declination_offset      5428 non-null   float64
#  43  angular_offset_right_ascension      5428 non-null   float64
#  44  angular_offset_declination          5428 non-null   float64
#  45  angular_offset_sky                  5428 non-null   float64
#  46  insolation_flux                     5428 non-null   float64
#  47  star_density                        5428 non-null   float64
# dtypes: float64(46), int64(1), object(1)
# memory usage: 2.0+ MB

# %%
# Split into X and y dataframes to use LabelEncoder() on the target variable
# Reconvert back into dataframe - target variable 'disposition' encoded as 'CONFIRMED' = 0, 'FALSE POSITIVE' = 1
X_binary_class = binary_class_df.drop('disposition', axis = 1)
y_binary_class = binary_class_df.disposition

lec = LabelEncoder()

y_binary_class = pd.DataFrame(lec.fit_transform(y_binary_class),
                              index = y_binary_class.index,
                              columns = y_binary_class.to_frame().columns)

binary_class_df = pd.concat([X_binary_class, y_binary_class], axis = 1)
binary_class_df
# Out:
#       num_of_objects_around_star  right_ascension  declination  g_band_mag  \
# 0                              2        291.93423    48.141651      15.890
# 1                              2        291.93423    48.141651      15.890
# 3                              1        285.53461    48.285210      16.100
# 4                              1        288.75488    48.226200      16.015
# 8                              1        298.86435    42.151569      12.999
# ...                          ...              ...          ...         ...
# 9557                           1        290.93597    47.290730      15.534
# 9558                           1        298.74921    46.973351      15.064
# 9559                           1        297.18875    47.093819      14.082
# 9561                           1        294.16489    47.176281      15.853
# 9563                           1        297.00977    47.121021      15.210
#
#       r_band_mag  i_band_mag  z_band_mag  j_band_mag  h_band_mag  k_band_mag  \
# 0         15.270      15.114      15.006      14.082      13.751      13.648
# 1         15.270      15.114      15.006      14.082      13.751      13.648
# 3         15.554      15.382      15.266      14.326      13.911      13.809
# 4         15.468      15.292      15.241      14.366      14.064      13.952
# 8         12.609      12.515      12.480      11.659      11.415      11.396
# ...          ...         ...         ...         ...         ...         ...
# 9557      14.863      14.643      14.487      13.487      13.066      12.926
# 9558      14.441      14.227      14.144      13.153      12.847      12.724
# 9559      13.501      13.299      13.177      12.200      11.814      11.756
# 9561      15.347      15.185      15.158      14.220      13.913      13.844
# 9563      14.781      14.662      14.647      13.830      13.522      13.512
#
#       ...  centroid_right_ascension_offset  centroid_declination_offset  \
# 0     ...                            0.430                        0.940
# 1     ...                           -0.630                        1.230
# 3     ...                           -0.111                        0.002
# 4     ...                           -0.010                        0.230
# 8     ...                          -13.450                       24.090
# ...   ...                              ...                          ...
# 9557  ...                           -1.000                       -0.300
# 9558  ...                            1.100                        1.200
# 9559  ...                            0.792                       -0.484
# 9561  ...                            7.200                       -5.600
# 9563  ...                            2.900                        8.900
#
#       planet_star_right_ascension_offset  planet_star_declination_offset  \
# 0                              -0.000200                       -0.000550
# 1                               0.000660                       -0.001050
# 3                               0.003020                       -0.001420
# 4                               0.000080                       -0.000070
# 8                               0.003032                       -0.005549
# ...                                  ...                             ...
# 9557                            0.000600                        0.000300
# 9558                           -0.000080                       -0.000100
# 9559                           -0.000237                        0.000178
# 9561                           -0.000720                        0.000500
# 9563                           -0.000230                       -0.000700
#
#       angular_offset_right_ascension  angular_offset_declination  \
# 0                             -0.010                       0.200
# 1                              0.390                       0.000
# 3                             -0.249                       0.147
# 4                              0.030                      -0.090
# 8                             -4.506                       7.710
# ...                              ...                         ...
# 9557                           2.360                      -0.990
# 9558                           1.260                      -1.200
# 9559                           2.132                      -1.757
# 9561                           3.410                      -3.650
# 9563                           1.020                       3.300
#
#       angular_offset_sky  insolation_flux  star_density  disposition
# 0                  0.200            93.59       3.20796            0
# 1                  0.390             9.11       3.02368            0
# 3                  0.289           891.96       0.22080            1
# 4                  0.100           926.16       1.98635            0
# 8                  8.930           767.22       0.00485            1
# ...                  ...              ...           ...          ...
# 9557               2.550             0.42       0.00771            1
# 9558               1.750           176.40       0.18863            1
# 9559               2.763          4500.53       0.16318            1
# 9561               5.000          5713.41       8.97692            1
# 9563               3.400           607.42       1.40645            1
#
# [5428 rows x 48 columns]

# %%
binary_class_df.to_csv('binary_class_data.csv')
